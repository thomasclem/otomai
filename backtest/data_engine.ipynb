# %%
import sys
sys.path.append('./')
from utilities.data_manager import ExchangeDataManager
import ccxt

# %% [markdown]
# # Download Historical data into CSV in Database

# %%
exchange = ccxt.bitget()

# %%
market = exchange.load_markets()

# %%
symbols = [s for s in market.keys() if s.endswith(":USDT")]

# %%
exchange_name = "bitget"

intervals = ["4h"]

coin_to_dl = [
    "IDOL/USDT:USDT",
]

exchange = ExchangeDataManager(
    exchange_name=exchange_name, path_download="database/exchanges"
)

await exchange.download_data(
    coins=symbols[-100:],
    intervals=intervals,
    start_date="2025-01-01 00:00:00"
)
# Out:
# 	Récupération pour la paire MUBARAK/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire NMR/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire TUT/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire FORM/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire RSS3/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BID/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SIREN/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BANANAS31/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BR/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire NIL/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire PARTI/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire NAVX/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire WAL/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire FUN/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire MLN/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire GUN/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire PUMPBTC/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire STO/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire XAUT/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire AMP/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BABY/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire FHE/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire PROMPT/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire RFC/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire KERNEL/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire WCT/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire 10000000AIDOGE/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BANK/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire EPT/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire HYPER/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ZORA/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire INIT/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire DOLO/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire FIS/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire JST/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire TAI/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SIGN/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire MILK/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire HAEDAL/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire PUNDIX/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire B2/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire GORK/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire HOUSE/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ASR/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ALPINE/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SYRUP/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire OBOL/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SXT/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SHM/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire DOOD/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SKYAI/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire LAUNCHCOIN/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire NXPC/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BADGER/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire AGT/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire AWE/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire RWA/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BLUE/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire B/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SOON/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ZBCN/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire HUMA/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SOPH/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire A/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ASRR/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BDXN/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire PORT3/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire LA/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire CUDIS/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SKATE/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire RESOLV/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire HOME/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire IDOL/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SQD/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire TAG/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/94 [00:00<?, ?it/s]
# 	Récupération pour la paire SPK/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BOMB/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire F/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire NEWT/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire DMC/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire H/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SAHARA/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire NODE/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire FRAG/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ICNT/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire M/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire CBK/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire CROSS/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BULLA/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire TANSSI/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire AIN/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire USELESS/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire PUMP/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire C/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire VELVET/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire TAC/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ES/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ERA/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire TA/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/94 [00:00<?, ?it/s]
# 	Récupération pour la paire ASP/USDT:USDT en timeframe 4h sur l'exchange bitget...
#   0%|          | 0/94 [00:00<?, ?it/s]

# %%
df = exchange.load_data(
    coin="ETH/USDT:USDT",
    interval="1h"
)

df

# %% [markdown]
# # Get Historical Data From Database

# %%
exchange_name = "binance"

exchange = ExchangeDataManager(
    exchange_name=exchange_name, path_download="./database/exchanges"
)

await exchange.download_data(
    coins=["MAGIC/USDT:USDT"],
    intervals=["15m"],
    start_date="2023-01-01 00:00:00"
)

df = exchange.load_data(
    coin="MAGIC/USDT:USDT",
    interval="15m"
)

df

# %%
df = exchange.load_data(
    coin="MAGIC/USDT:USDT",
    interval="15m"
)

df

# %%
len(symbols[-50:])
